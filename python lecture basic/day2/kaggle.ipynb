# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#파일 read 및 shape 확인
raw = pd.read_csv("kaggle_survey_2020_responses.csv")
# Out:
# C:\Users\Galaxy\AppData\Local\Temp\ipykernel_8796\615060621.py:2: DtypeWarning: Columns (0,18,31,45,50,63,80,92,99,105,130,171,187,241,254,266,278,289,307,322,330,342,353) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw = pd.read_csv("kaggle_survey_2020_responses.csv")

# %%
raw.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                1838                        35-39
# 2                              289287                        30-34
# 3                                 860                        35-39
# 4                                 507                        30-34
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                   Colombia
# 2                   United States of America
# 3                                  Argentina
# 4                   United States of America
#
# ...

# %% [markdown]
# ```python
# pd.read_csv('파일명', encoding = 'cp949', low_memory = False)
# ```
#
# csv파일에 한글이 포함되어 있는 경우에는 상기와 같이 encoding을 'cp949' 또는 'ms949'로 설정할 필요가 있다.
#
# low_memory옵션은 대용량의 데이터를 불러오는 경우 각 칼럼의 데이터 타입(dtype)을 추측하는 것이 매우 많은 메모리를 사용하기 때문에 대용량의 데이터를 불러올때 메모리 에러가 발생하는 경우 이를 False로 설정하거나 dtype을 명시해주어야한다.

# %%
#head 확인
raw.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                1838                        35-39
# 2                              289287                        30-34
# 3                                 860                        35-39
# 4                                 507                        30-34
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                   Colombia
# 2                   United States of America
# 3                                  Argentina
# 4                   United States of America
#
# ...

# %%
#질문 뽑아오기
question = raw.iloc[0]
question
# Out:
# Time from Start to Finish (seconds)                                Duration (in seconds)
# Q1                                                           What is your age (# years)?
# Q2                                                What is your gender? - Selected Choice
# Q3                                             In which country do you currently reside?
# Q4                                     What is the highest level of formal education ...
#                                                              ...
# Q35_B_Part_7                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_8                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_9                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_10                          In the next 2 years, do you hope to become mor...
# Q35_B_OTHER                            In the next 2 years, do you hope to become mor...
# ...

# %%
#질문을 제외한 답안데이터만 남기기
answer = raw.drop([0]) #raw.iloc[1:]오 같음
answer
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2  \
# 1                                    1838  35-39    Man
# 2                                  289287  30-34    Man
# 3                                     860  35-39    Man
# 4                                     507  30-34    Man
# 5                                      78  30-34    Man
# ...                                   ...    ...    ...
# 20032                                 126  18-21    Man
# 20033                                 566  55-59  Woman
# 20034                                 238  30-34    Man
# 20035                                 625  22-24    Man
# 20036                                1031  22-24    Man
#
#                                                       Q3  \
# 1                                               Colombia
# 2                               United States of America
# 3                                              Argentina
# 4                               United States of America
# ...

# %%
#정보확인
answer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20036 entries, 1 to 20036
# Columns: 355 entries, Time from Start to Finish (seconds) to Q35_B_OTHER
# dtypes: object(355)
# memory usage: 54.3+ MB

# %%
#question 에서 Q1 확인
question["Q1"]
# Out:
# 'What is your age (# years)?'

# %%
answer["Q1"]
# Out:
# 1        35-39
# 2        30-34
# 3        35-39
# 4        30-34
# 5        30-34
#          ...
# 20032    18-21
# 20033    55-59
# 20034    30-34
# 20035    22-24
# 20036    22-24
# Name: Q1, Length: 20036, dtype: object

# %%
#Q1 항목의 답안 count
Q1 = answer['Q1'].value_counts().sort_index()
Q1
# Out:
# Q1
# 18-21    3469
# 22-24    3786
# 25-29    4011
# 30-34    2811
# 35-39    1991
# 40-44    1397
# 45-49     988
# 50-54     698
# 55-59     411
# 60-69     398
# 70+        76
# Name: count, dtype: int64

# %%
answer.sort_values("Q1")
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2  \
# 6079                                   33  18-21  Woman
# 13969                                 408  18-21    Man
# 13964                                 540  18-21    Man
# 8718                                  108  18-21    Man
# 13958                                 290  18-21    Man
# ...                                   ...    ...    ...
# 10784                                6704    70+    Man
# 13661                                 357    70+    Man
# 5776                                  876    70+    Man
# 8979                                  756    70+    Man
# 19824                                1720    70+    Man
#
#                                                       Q3  \
# 6079                                             Germany
# 13969  United Kingdom of Great Britain and Northern I...
# 13964                                             Mexico
# 8718                                           Australia
# ...

# %%
#Q1 plot
sns.countplot(data=answer.sort_values("Q1"), x="Q1", 
              palette="Blues_r").set_title(question["Q1"])
# Out:
# Text(0.5, 1.0, 'What is your age (# years)?')

# %%
#Q2 항목의 답안에 대한 value count
question_no = 'Q2'

Q2 = answer[question_no].value_counts().sort_index()
Q2
# Out:
# Q2
# Man                        15789
# Nonbinary                     52
# Prefer not to say            263
# Prefer to self-describe       54
# Woman                       3878
# Name: count, dtype: int64

# %%
#Q2 Plot
sns.countplot(data = answer    , y= question_no     ).set_title( question[question_no]         )
# Out:
# Text(0.5, 1.0, 'What is your gender? - Selected Choice')

# %%
#crosstab으로 Q1 Q2 결과 합치기
q1q2 = pd.crosstab(answer["Q1"],answer["Q2"])

#Q1 Q2 bar plot 및 x 축 각도 조절
q1q2[["Man", "Woman"]].plot.bar()
q1q2[["Man", "Woman"]].plot.bar(rot=0)
q1q2[["Man", "Woman"]].plot.bar(rot=30)
# Out:
# <Axes: xlabel='Q1'>

# %%
#내림차순으로 index 정렬하여 가로로 출력
q1q2[["Man", "Woman"]].plot.barh()
q1q2[["Man", "Woman"]].plot.barh(rot=0)
q1q2[["Man", "Woman"]].plot.barh(rot=30)
# Out:
# <Axes: ylabel='Q1'>

# %%
q1q2[["Man", "Woman"]].sort_index(ascending = False).plot.barh(rot = 30) #순서 반대로 뒤집기
# Out:
# <Axes: ylabel='Q1'>

# %%
#plot 공간을 만들고
plt.figure(figsize = (10,6))

#Q1 value를 기준으로 출력하되 Q2 기준으로 구분
sns.countplot(data = answer.sort_values("Q1")      , x =   "Q1"    , hue=  "Q2"         )
# Out:
# <Axes: xlabel='Q1', ylabel='count'>

# %%
#위에서 알아낸 패턴에 따라 countplot을 생성해주는 함수 선언

def show_countplot_by_qno(qno, fsize=(10,6), order = None):
    """_summary_

    Args:
        qno (_type_): _description_
        fsize (tuple, optional): _description_. Defaults to (10,6).
        order (_type_, optional): _description_. Defaults to None.
    """
    #만약 order값을 지정하지않아 기본값인 None이 들어갈 경우,
    #아래 order 옵션에서 에러가 나므로 index를 뽑아서 넘겨야한다.
    if not order:
        order = answer[qno].value_counts().index
    
    plt.figure(figsize = fsize)
    sns.countplot(data = answer,
                  y = qno,
                  order = order,
                  palette='Blues_r').set_title(question[qno])

# %%
#함수를 활용해 Q3 항목 countplot
# question_no = "Q3"
# Q3 = answer[question_no].value_counts().sort_index()
# Q3

show_countplot_by_qno("Q3",fsize = (12,12))

# %%
#함수를 활용해 Q4 항목 countplot
show_countplot_by_qno("Q4")

# %%
#함수를 활용해 Q5 항목 countplot
show_countplot_by_qno("Q5")

# %%
#함수를 활용해 Q6 항목 countplot
show_countplot_by_qno("Q6")

# %%
#함수를 활용해 Q7 항목 countplot -> err -> 왜?
q7_title = question.filter(regex = "Q7")[0].split("-")[0] #정규 표현식 이용
q7_title
# Out:
# 'What programming languages do you use on a regular basis? (Select all that apply) '

# %%
#question에서 Q6이후 값 확인
question[7:20]
# Out:
# Q7_Part_1     What programming languages do you use on a reg...
# Q7_Part_2     What programming languages do you use on a reg...
# Q7_Part_3     What programming languages do you use on a reg...
# Q7_Part_4     What programming languages do you use on a reg...
# Q7_Part_5     What programming languages do you use on a reg...
# Q7_Part_6     What programming languages do you use on a reg...
# Q7_Part_7     What programming languages do you use on a reg...
# Q7_Part_8     What programming languages do you use on a reg...
# Q7_Part_9     What programming languages do you use on a reg...
# Q7_Part_10    What programming languages do you use on a reg...
# Q7_Part_11    What programming languages do you use on a reg...
# Q7_Part_12    What programming languages do you use on a reg...
# Q7_OTHER      What programming languages do you use on a reg...
# Name: 0, dtype: object

# %%
#Q7이 포함된 답안 컬럼 뽑아내기
answer_Q7 = answer.filter(regex = "Q7")
answer_Q7
# Out:
#       Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6   Q7_Part_7  \
# 1        Python         R       SQL         C       NaN       NaN  Javascript
# 2        Python         R       SQL       NaN       NaN       NaN         NaN
# 3           NaN       NaN       NaN       NaN       NaN      Java  Javascript
# 4        Python       NaN       SQL       NaN       NaN       NaN         NaN
# 5        Python       NaN       NaN       NaN       NaN       NaN         NaN
# ...         ...       ...       ...       ...       ...       ...         ...
# 20032       NaN       NaN       NaN       NaN       NaN       NaN         NaN
# 20033    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 20034    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 20035    Python       NaN       SQL         C       NaN      Java  Javascript
# 20036    Python       NaN       NaN       NaN       NaN       NaN         NaN
#
# ...

# %%
answer_Q7_desc = answer_Q7.describe() #describe() : 기본 통계값 분석
answer_Q7_desc
# Out:
#        Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6  \
# count      15530      4277      7535      3315      3827      3367
# unique         1         1         1         1         1         1
# top       Python         R       SQL         C       C++      Java
# freq       15530      4277      7535      3315      3827      3367
#
#          Q7_Part_7 Q7_Part_8 Q7_Part_9 Q7_Part_10 Q7_Part_11 Q7_Part_12  \
# count         2995       262       198       1776       2217          0
# unique           1         1         1          1          1          0
# top     Javascript     Julia     Swift       Bash     MATLAB        NaN
# freq          2995       262       198       1776       2217        NaN
#
#        Q7_OTHER
# count      1945
# unique        1
# top       Other
# freq       1945

# %%
#describe 데이터 프레임 이용하기
answer_Q7_count = answer_Q7_desc.loc[["count" ,  "top"]].T #T : 열과 행 전환
answer_Q7_count = answer_Q7_count.set_index("top").sort_values("count", ascending = False ) #count 값 기준으로 역 정렬
answer_Q7_count
# Out:
#             count
# top
# Python      15530
# SQL          7535
# R            4277
# C++          3827
# Java         3367
# C            3315
# Javascript   2995
# MATLAB       2217
# Other        1945
# Bash         1776
# Julia         262
# Swift         198
# NaN             0

# %%
#Q7 항목 plot
sns.barplot(data = answer_Q7_count , y = answer_Q7_count.index , x = "count",  palette = "Blues_r").set_title(q7_title) #palette : 알록달록 없애기
# Out:
# Text(0.5, 1.0, 'What programming languages do you use on a regular basis? (Select all that apply) ')

# %%
#question 번호에 따라 question title을 뽑아주는 함수 생성
def get_question_title_by_qno(qno):
    if qno in question.index :
        return question[qno]
    else:
        q_no = question.filter(regex = qno)[0].split("-")[0] #정규 표현식 이용
        return q_no

# %%
#함수를 활용해 Q7 title 확인
get_question_title_by_qno("Q7")
# Out:
# 'What programming languages do you use on a regular basis? (Select all that apply) '

# %%
#multiple choice 문항의 답안을 처리해주는 함수생성
def get_multiple_choice_answer_by_qno(qno):
    df_answer = answer.filter(regex = qno)
    df_desc = df_answer.describe()
    df_count = df_desc.loc[["count" ,  "top"]].T #T : 열과 행 전환
    df_count = df_count.set_index("top").sort_values( by = "count", ascending = False ) #count 값 기준으로 역 정렬
    return df_count

get_multiple_choice_answer_by_qno("Q9")

# %%
#multiple choice 문항을 bar plot으로 보여주는 함수 생성
def show_multiple_choice_bar_plot_by_qno(qno):
    multiple_choice_answer = get_multiple_choice_answer_by_qno(qno)
    plt.figure(figsize  = (10,6))
    sns.barplot(data = multiple_choice_answer , y = multiple_choice_answer.index , x = "count" ,  palette = "Blues_r").set_title(get_question_title_by_qno(qno)) #palette : 알록달록 없애기
    
show_multiple_choice_bar_plot_by_qno("Q7")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[79], line 7
#       4     plt.figure(figsize  = (10,6))
#       5     sns.barplot(data = multiple_choice_answer , y = multiple_choice_answer.index , x = "count" ,  palette = "Blues_r").set_title(get_question_title_by_qno(qno)) #palette : 알록달록 없애기
# ----> 7 show_multiple_choice_bar_plot_by_qno("Q7")
#
# Cell In[79], line 5, in show_multiple_choice_bar_plot_by_qno(qno)
#       3 multiple_choice_answer = get_multiple_choice_answer_by_qno(qno)
#       4 plt.figure(figsize  = (10,6))
# ----> 5 sns.barplot(data = multiple_choice_answer , y = multiple_choice_answer.index , x = "count" ,  palette = "Blues_r").set_title(get_question_title_by_qno(qno))
#
# AttributeError: 'NoneType' object has no attribute 'index'

# %%
#multiple choice 문항의 선택지 받아오기
q7_cols = answer.filter(regex = "Q7").describe().loc["top"].tolist()
q7_cols
# Out:
# ['Python',
#  'R',
#  'SQL',
#  'C',
#  'C++',
#  'Java',
#  'Javascript',
#  'Julia',
#  'Swift',
#  'Bash',
#  'MATLAB',
#  nan,
#  'Other']

# %%
#Q2 Q7 으로 시작하는 모든 문항의 답안 받아오기
q2q7 = answer.filter(regex = "Q7|Q2$") #$ : q2로 정확하게 시작하고 맞춰지는 거 구분

#Q2를 기준으로 그룹화
q2q7_count = q2q7.groupby("Q2").count()

#column 재지정
q2q7_count.columns = q7_cols
q2q7_count
# Out:
#                          Python     R   SQL     C   C++  Java  Javascript  \
# Q2
# Man                       12530  3299  5940  2552  3063  2641        2487
# Nonbinary                    41    14    20     8    10     1           6
# Prefer not to say           182    48    97    36    43    42          41
# Prefer to self-describe      41     8    18    12    13     9          12
# Woman                      2736   908  1460   707   698   674         449
#
#                          Julia  Swift  Bash  MATLAB  NaN  Other
# Q2
# Man                        238    171  1561    1679    0   1634
# Nonbinary                    1      2    10       7    0      7
# Prefer not to say            5      4    31      28    0     31
# Prefer to self-describe      2      1    10       6    0      7
# Woman                       16     20   164     497    0    266

# %%
#Man과 Woman에 해당하는 데이터를 받아 bar plot
q2q7_count.loc[['Man','Woman']].T.sort_values("Woman").plot.barh()
# Out:
# <Axes: >

# %%
question.index
# Out:
# Index(['Time from Start to Finish (seconds)', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5',
#        'Q6', 'Q7_Part_1', 'Q7_Part_2', 'Q7_Part_3',
#        ...
#        'Q35_B_Part_2', 'Q35_B_Part_3', 'Q35_B_Part_4', 'Q35_B_Part_5',
#        'Q35_B_Part_6', 'Q35_B_Part_7', 'Q35_B_Part_8', 'Q35_B_Part_9',
#        'Q35_B_Part_10', 'Q35_B_OTHER'],
#       dtype='object', length=355)

# %%
#앞에서 만들었던 함수를 조합하여 count plot, multiple choice 문항 bar plot 두개 모두 가능한 plot 함수 만들기 (종합)
def show_plot_by_qno(qno):
    if qno in question.index:
        show_countplot_by_qno(qno)
    else:
        show_multiple_choice_bar_plot_by_qno(qno)

# %%
#위 함수를 사용하여 Q8 확인

show_plot_by_qno("Q8")

# %%
#위 함수를 사용하여 Q9 확인
show_plot_by_qno("Q9")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 2
#       1 #위 함수를 사용하여 Q9 확인
# ----> 2 show_plot_by_qno("Q9")
#
# Cell In[99], line 6, in show_plot_by_qno(qno)
#       4     show_countplot_by_qno(qno)
#       5 else:
# ----> 6     show_multiple_choice_bar_plot_by_qno(qno)
#
# Cell In[79], line 5, in show_multiple_choice_bar_plot_by_qno(qno)
#       3 multiple_choice_answer = get_multiple_choice_answer_by_qno(qno)
#       4 plt.figure(figsize  = (10,6))
# ----> 5 sns.barplot(data = multiple_choice_answer , y = multiple_choice_answer.index , x = "count" ,  palette = "Blues_r").set_title(get_question_title_by_qno(qno))
#
# AttributeError: 'NoneType' object has no attribute 'index'

# %%
#위 함수를 사용하여 Q10 확인
show_plot_by_qno("Q10")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[109], line 2
#       1 #위 함수를 사용하여 Q10 확인
# ----> 2 show_plot_by_qno("Q10")
#
# Cell In[99], line 6, in show_plot_by_qno(qno)
#       4     show_countplot_by_qno(qno)
#       5 else:
# ----> 6     show_multiple_choice_bar_plot_by_qno(qno)
#
# Cell In[79], line 5, in show_multiple_choice_bar_plot_by_qno(qno)
#       3 multiple_choice_answer = get_multiple_choice_answer_by_qno(qno)
#       4 plt.figure(figsize  = (10,6))
# ----> 5 sns.barplot(data = multiple_choice_answer , y = multiple_choice_answer.index , x = "count" ,  palette = "Blues_r").set_title(get_question_title_by_qno(qno))
#
# AttributeError: 'NoneType' object has no attribute 'index'

# %%
#위 함수를 사용하여 Q11 확인
show_plot_by_qno("Q11")

# %%
#위 함수를 사용하여 Q12 ~ Q23 확인
for i in range(12,24):
    strings =  "Q" + str(i)
    show_plot_by_qno(strings)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 3
#       1 #위 함수를 사용하여 Q12 ~ Q23 확인
#       2 for i in range(12,24):
# ----> 3     strings =  "Q" + str(i)
#       4     show_plot_by_qno(strings)
#
# TypeError: 'str' object is not callable

# %%
show_plot_by_qno("Q24") #보기에 불편한점?

# %%
#Q24
q24_count = answer["Q24"].value_counts().reset_index()
q24_count.columns = ["range","count"]
q24_count
# Out:
#               range  count
# 0            $0-999   2128
# 1     10,000-14,999    665
# 2       1,000-1,999    581
# 3   100,000-124,999    573
# 4     40,000-49,999    552
# 5     30,000-39,999    540
# 6     50,000-59,999    510
# 7       5,000-7,499    488
# 8     15,000-19,999    449
# 9     60,000-69,999    408
# 10    20,000-24,999    404
# 11    70,000-79,999    394
# 12      7,500-9,999    371
# 13  150,000-199,999    347
# 14      2,000-2,999    330
# 15  125,000-149,999    315
# 16    25,000-29,999    310
# 17    90,000-99,999    280
# 18      4,000-4,999    279
# 19    80,000-89,999    273
# 20      3,000-3,999    264
# 21  200,000-249,999    115
# 22  300,000-500,000     55
# 23       > $500,000     50
# 24  250,000-299,999     48

# %%
#expand = True 하면 split된 결과를 바로 컬럼으로 생성해준다
#",|\$|>", "", regex=True
q24_count['min'] = q24_count["range"].str.split("-", expand = True)[0]
q24_count['max'] = q24_count["range"].str.split("-", expand = True)[1]
q24_count

# %%
#count가아닌 range 기준으로 정렬하여 Q24 plot
plt.figure(figsize=(10,6))

# %%
#range 열을 order로 사용하기위해 list로 변경
q24_cols=

# %%
#한국 정보만 뽑아서 보기
q3_korea = 

plt.figure(figsize=(10, 6))

# %%
#함수를 사용하여 Q25 확인

# %%
#함수를 사용하여 Q26 확인 - 새로운줄이 나타난이유?

# %%
#Q26을 포함하는 컬럼 확인
answer.filter(regex="Q26").iloc[0]

# %%
#Q26_A 확인

# %%
#Q26_B 확인

# %% [markdown]
# ## Q27_A ~ Q38 은 직접 확인해보세요!

# %%
#마지막 문항 Q39 확인
